# %% [markdown]
# # _3D Video with Python_

# %% [markdown]
# <img src='un-50.webp'>

# %% [markdown]
# _Bu proje, Python kullanarak **3D bir görselleştirmeyi video haline getirmeyi** göstermektedir._
#
# _Temel adımlar:_
#
# 1. _**3D Veri ve Grafik Oluşturma:**_
#    _`numpy` ile veri noktaları oluşturulur ve `matplotlib` ile 3D kontur grafiği çizilir._
#
# 2. _**Görünümü Ayarlama ve Panelleri Gizleme:**_
#    _3D eksenlerin görünümü ayarlanır, paneller ve gridler arka plana uygun şekilde şeffaf yapılır._
#
# 3. _**Farklı Açılardan Görseller Oluşturma:**_
#    _Grafik farklı açılardan kaydedilir (0° → 360°)._
#
# 4. _**GIF Oluşturma (Video Simülasyonu):**_
#    _Oluşturulan tüm görseller birleştirilip `PIL` ile GIF formatında kaydedilir._
#
# ---
#
# 📌 _**Not:** Video, 40ms gecikmeli ve sonsuz döngüye sahip bir GIF olarak kaydedilir._

# %% [markdown]
# ## _Import_

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os

# %% [markdown]
# ## _3D Veri Oluşturma_

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-15, 15, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) + np.cos(Y)

# %% [markdown]
# ## _Görselleri kaydetmek için klasör oluştur_

# %%
os.makedirs("3d", exist_ok=True)

# %% [markdown]
# ## _Farklı açılardan görseller oluştur_

# %%
for angle in range(0, 360, 2):
    fig = plt.figure(figsize=(9, 6))
    ax = fig.add_subplot(111, projection='3d')
    
    # Eksenleri ve gridleri gizle
    ax._axis3don = False
    for axis in [ax.xaxis, ax.yaxis, ax.zaxis]:
        axis.set_pane_color((1, 1, 1, 0))
        axis._axinfo['grid']['color'] = (1, 1, 1, 0)
    
    # 3D kontur grafiği
    ax.contour3D(X, Y, Z, 100, cmap='viridis')
    ax.view_init(60, angle)
    
    plt.savefig(f"3d/3d_vis_{angle}.png", dpi=75)
    plt.close()

# %% [markdown]
# ## _GIF Oluşturma_

# %%
frames = [Image.open(f"3d/3d_vis_{i}.png") for i in range(0, 360, 2)]
frames[0].save('3d_vis.gif', format='GIF',
               append_images=frames[1:],
               save_all=True,
               duration=40,
               loop=0)

print("GIF oluşturuldu: 3d_vis.gif")
# Out:
# GIF oluşturuldu: 3d_vis.gif
